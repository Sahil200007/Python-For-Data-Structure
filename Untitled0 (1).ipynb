# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# a. Write a Python program to import a CSV dataset using Pandas and
# display the first 5 and last 5 records.

# %%
import pandas as pd

# %%
df = pd.read_csv("Students.csv")

# %%
print(df.head())
# Out:
#    Roll No   Name Department  Marks  Attendance
# 0      101   Amit     BSc IT     78          85
# 1      102  Priya     BSc CS     65          90
# 2      103  Rahul     BSc IT     88          92
# 3      104   Neha     BSc CS     72          80
# 4      105  Rohan     BSc IT     55          70

# %% [markdown]
# Print Last 5 Values.

# %%
print(df.tail())
# Out:
#    Roll No   Name Department  Marks  Attendance
# 0      101   Amit     BSc IT     78          85
# 1      102  Priya     BSc CS     65          90
# 2      103  Rahul     BSc IT     88          92
# 3      104   Neha     BSc CS     72          80
# 4      105  Rohan     BSc IT     55          70

# %% [markdown]
# b. Write a Python program to analyze the dataset by displaying the number of
# rows and columns, column names, data types, and basic statistical information.

# %% [markdown]
# Number of Rows and Column

# %%
print(df.shape)
# Out:
# (5, 5)

# %%
print(df.columns)
# Out:
# Index(['Roll No', 'Name', 'Department', 'Marks', 'Attendance'], dtype='object')

# %%
print(df.dtypes)
# Out:
# Roll No        int64
# Name          object
# Department    object
# Marks          int64
# Attendance     int64
# dtype: object

# %%
print(df.describe)
# Out:
# <bound method NDFrame.describe of    Roll No   Name Department  Marks  Attendance
# 0      101   Amit     BSc IT     78          85
# 1      102  Priya     BSc CS     65          90
# 2      103  Rahul     BSc IT     88          92
# 3      104   Neha     BSc CS     72          80
# 4      105  Rohan     BSc IT     55          70>

# %% [markdown]
# c. Write a Python program to filter records from the dataset using
# conditions. For example, display students having marks greater than 60

# %%
result = df[df["Attendance"]>=90]
print(result)
# Out:
#    Roll No   Name Department  Marks  Attendance
# 1      102  Priya     BSc CS     65          90
# 2      103  Rahul     BSc IT     88          92

# %% [markdown]
# d. Write a Python program to sort the dataset based on a selected column
# and display the top 5 records. For example, sort students by marks or products
# by price.

# %%
result = df.sort_values("Marks")
print(result)
# Out:
#    Roll No   Name Department  Marks  Attendance
# 4      105  Rohan     BSc IT     55          70
# 1      102  Priya     BSc CS     65          90
# 3      104   Neha     BSc CS     72          80
# 0      101   Amit     BSc IT     78          85
# 2      103  Rahul     BSc IT     88          92

# %% [markdown]
# e. Write a Python program to perform data analysis on the dataset by
# finding the maximum, minimum, average, and total values of a numerical
# column.

# %%
print("Maximum Marks ",df["Marks"].max())
print("Minimum Marks ",df["Marks"].min())
# Out:
# Maximum Marks  88
# Minimum Marks  55
